# %% [markdown]
# # I.I.D Return Model
#
# Assume that the asset price follow the Black-Scholes Model:
# $\frac{dS_t}{S_t} = (r\mathbf{1} + \Sigma\lambda)dt + \Sigma dZ_t$
#
# Then excess stock return given by $ R_k = \exp\left((r \cdot \mathbf{1} + \Sigma\lambda - \frac{1}{2}\text{diag}(\Sigma \cdot \Sigma^T)) \Delta + \sqrt{\Delta} \Sigma \epsilon_k\right) - R_f \mathbf{1} $, where $ \epsilon_t $ follows a multivariate normal distribution $ N_p(\mathbf{0}, I_p) $
#
# $s_k = W_k$, $\eta_k = R_k$, $W_{k+1} = W_k(g_k^TR_k + R_f)$, and $s_{k+1} = W_{k+1}$

# %%
import torch
import torch.nn as nn
from torch import Tensor

class PortfolioModel(nn.Module):
    def __init__(self, r, P, cov, Lambda, Delta, K, lb, ub,Rf,batch_size):
        super(PortfolioModel, self).__init__()
        self.K = K
        self.Rf = Rf
        self.batch_size = batch_size
        self.stack_layers = nn.ModuleList()
        for i in range(K):
            self.stack_layers.append(StackLayer(r, P, cov, Lambda, Delta, K, lb, ub,Rf,batch_size))
    
    def forward(self,inputs):
        print('initial portfolio wealth: 1')
        for i in range(self.K):
            print('subnetwork {}'.format(i))
            inputs = self.stack_layers[i](inputs)            
        return inputs

class Subnetwork(nn.Module):
    def __init__(self, r, P, cov, Lambda, Delta, K, lb, ub,Rf, batch_size):
        super(Subnetwork, self).__init__()
        self.Rf = Rf
        self.lb = lb
        self.ub = ub
        epsilon = np.random.multivariate_normal(mean=np.zeros(int(P)), cov=np.eye(int(P))) 
        self.R = np.zeros((batch_size, P))
        for b in range(batch_size):          
                epsilon = np.random.multivariate_normal(mean=np.zeros(P), cov=np.eye(P))
                self.R[b, :] = np.exp((r * np.ones(P) + cov @ Lambda - (1/2) * np.diag(cov @ cov.T)) * Delta +
                    np.sqrt(Delta) * cov @ epsilon) - Rf * np.ones(P)
        self.R = torch.Tensor(self.R)
        self.subnetwork = nn.Sequential(
            nn.Linear(5, 5, bias=False),
            nn.Tanh(),
            nn.Linear(5, 5, bias=False),
            nn.Tanh(),
            nn.Linear(5, 5, bias=False),
            nn.Tanh(),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        state_variable = x 
        out = self.R 
        weights = self.subnetwork(out)
        print("weights before rebalancing:", weights.detach().numpy())
        
        output = torch.stack([self.rebalance(batch, self.lb, self.ub) for batch in weights])
        print('weights after rebalancing',output.detach().numpy())
#         print('self.R', self.R.shape)
#         print('self.Rf',self.Rf.shape)

        updated_state_variable = torch.stack([torch.sum(state_variable[i] * output[i] * (1+self.R[i])* self.Rf) for i in range(output.shape[0])])
#         print('returns',self.R+1)
#         print('Rf',self.Rf)
#         print(((output * (self.R + Rf)).sum())
        print('new portfolio wealth:', updated_state_variable.detach().numpy())
        return updated_state_variable 

    def rebalance(self, weight, lb, ub):
        old = weight
        new = torch.clamp(old, lb, ub)
        while True:
            leftover = (old - new).sum()
            other_stocks = new[torch.where(new != ub)[0]]
            reassign = leftover * (other_stocks/other_stocks.sum())
            new[torch.where(new != ub)[0]] += reassign 
            old = new
            if len(torch.where(new > ub)[0]) == 0:
                break
            else:
                new = torch.clamp(old, lb, ub)
        return new
    
class StackLayer(nn.Module):
    def __init__(self, r, P, cov, Lambda, Delta, K, lb, ub,Rf,batch_size):
        super(StackLayer, self).__init__()
        self.blocks = nn.ModuleList([Subnetwork(r, P, cov, Lambda, Delta, K, lb, ub,Rf,batch_size)])   
    def forward(self, inputs):
        outputs = inputs 
        for block in self.blocks:
            outputs = block(outputs)
        return outputs

# %%
K=2 
model_2 = PortfolioModel(r, P, cov, Lambda, Delta, K, lb, ub, Rf, batch_size)
print(model_2)
# Out:
# PortfolioModel(
#   (stack_layers): ModuleList(
#     (0): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#     (1): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# $R_r = \tanh(\theta_{r-1} R_{r-1} + C_{r-1}), \quad r = 1, \ldots, L$
#
# Here, $C_{r-1}$ is the bias or risk-free rate, but since you are using excess return, there is no bias term.

# %%
K=10
model_10 = PortfolioModel(r, P, cov, Lambda, Delta, K, lb, ub, Rf, batch_size)
print(model_10)
# Out:
# PortfolioModel(
#   (stack_layers): ModuleList(
#     (0): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#     (1): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#     (2): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#     (3): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#     (4): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#     (5): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#     (6): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#     (7): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#     (8): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#     (9): StackLayer(
#       (blocks): ModuleList(
#         (0): Subnetwork(
#           (subnetwork): Sequential(
#             (0): Linear(in_features=5, out_features=5, bias=False)
#             (1): Tanh()
#             (2): Linear(in_features=5, out_features=5, bias=False)
#             (3): Tanh()
#             (4): Linear(in_features=5, out_features=5, bias=False)
#             (5): Tanh()
#             (6): Softmax(dim=1)
#           )
#         )
#       )
#     )
#   )
# )

# %%
P = 5 # number of stocks
cov = np.array([[0.15, 0.01, 0.01, 0.01, 0.01],
                [0.01, 0.15, 0.01, 0.01, 0.01],
                [0.01, 0.01, 0.15, 0.01, 0.01],
                [0.01, 0.01, 0.01, 0.15, 0.01],
                [0.01, 0.01, 0.01, 0.01, 0.15]]) 
Lambda = np.array([0.1, 0.1, 0.2, 0.2, 0.2])
Delta = 1 / 40 
r = 0.03 # return rate
Rf = np.exp(r * Delta) # risk free rate
K = 40 # number of period
M = 20000 # number of path 
lb =0 
ub = 0.5
K = 40
batch_size = 1 
model = PortfolioModel(r, P, cov, Lambda, Delta, K, lb, ub, Rf, batch_size)
inputs = torch.ones(1)
model(inputs)
# Out:
# initial portfolio wealth: 1
# subnetwork 0
# weights before rebalancing: [[0.2002924  0.20074396 0.19866765 0.20000793 0.20028809]]
# weights after rebalancing [[0.2002924  0.20074396 0.19866765 0.20000793 0.20028809]]
# new portfolio wealth: [1.0198796]
# subnetwork 1
# weights before rebalancing: [[0.19870317 0.19709319 0.20235746 0.20152672 0.20031945]]
# weights after rebalancing [[0.19870317 0.19709319 0.20235746 0.20152672 0.20031945]]
# new portfolio wealth: [1.0036745]
# subnetwork 2
# weights before rebalancing: [[0.20023754 0.20000373 0.19977735 0.20001858 0.19996284]]
# weights after rebalancing [[0.20023754 0.20000373 0.19977735 0.20001858 0.19996284]]
# new portfolio wealth: [0.99750245]
# subnetwork 3
# weights before rebalancing: [[0.2001481  0.2000365  0.19988889 0.19996502 0.19996153]]
# weights after rebalancing [[0.2001481  0.2000365  0.19988889 0.19996502 0.19996153]]
# new portfolio wealth: [1.0047791]
# subnetwork 4
# weights before rebalancing: [[0.20017849 0.20054574 0.20025286 0.20015903 0.19886383]]
# weights after rebalancing [[0.20017849 0.20054574 0.20025286 0.20015903 0.19886383]]
# new portfolio wealth: [1.0124696]
# subnetwork 5
# weights before rebalancing: [[0.20037724 0.19925599 0.2009286  0.19954583 0.19989234]]
# weights after rebalancing [[0.20037724 0.19925599 0.2009286  0.19954583 0.19989234]]
# new portfolio wealth: [1.000313]
# subnetwork 6
# weights before rebalancing: [[0.19923344 0.20070654 0.20024607 0.19930579 0.20050818]]
# weights after rebalancing [[0.19923344 0.20070654 0.20024607 0.19930579 0.20050818]]
# new portfolio wealth: [0.99080837]
# subnetwork 7
# weights before rebalancing: [[0.19972594 0.20020583 0.1995019  0.20009257 0.20047373]]
# weights after rebalancing [[0.19972594 0.20020583 0.1995019  0.20009257 0.20047373]]
# new portfolio wealth: [0.97203064]
# subnetwork 8
# weights before rebalancing: [[0.1997911  0.20057553 0.20028923 0.200188   0.19915609]]
# weights after rebalancing [[0.1997911  0.20057553 0.20028923 0.200188   0.19915609]]
# new portfolio wealth: [0.9808265]
# subnetwork 9
# weights before rebalancing: [[0.20050032 0.2002073  0.19994223 0.19974014 0.19961008]]
# weights after rebalancing [[0.20050032 0.2002073  0.19994223 0.19974014 0.19961008]]
# new portfolio wealth: [0.9978931]
# subnetwork 10
# weights before rebalancing: [[0.19994113 0.20019794 0.19981381 0.19997819 0.20006895]]
# weights after rebalancing [[0.19994113 0.20019794 0.19981381 0.19997819 0.20006895]]
# new portfolio wealth: [0.99497724]
# subnetwork 11
# weights before rebalancing: [[0.20053712 0.20041344 0.19910114 0.20028692 0.19966136]]
# weights after rebalancing [[0.20053712 0.20041344 0.19910114 0.20028692 0.19966136]]
# new portfolio wealth: [0.99257624]
# subnetwork 12
# weights before rebalancing: [[0.19914082 0.20248821 0.19911294 0.20010798 0.19915007]]
# weights after rebalancing [[0.19914082 0.20248821 0.19911294 0.20010798 0.19915007]]
# new portfolio wealth: [1.0160425]
# subnetwork 13
# weights before rebalancing: [[0.2003671  0.20012617 0.2002507  0.19992793 0.19932808]]
# weights after rebalancing [[0.2003671  0.20012617 0.2002507  0.19992793 0.19932808]]
# new portfolio wealth: [1.0069851]
# subnetwork 14
# weights before rebalancing: [[0.200333   0.20031174 0.19875748 0.20015992 0.20043789]]
# weights after rebalancing [[0.200333   0.20031174 0.19875748 0.20015992 0.20043789]]
# new portfolio wealth: [1.0220596]
# subnetwork 15
# weights before rebalancing: [[0.2002736  0.20045117 0.19926797 0.19971424 0.20029299]]
# weights after rebalancing [[0.2002736  0.20045117 0.19926797 0.19971424 0.20029299]]
# new portfolio wealth: [1.0297482]
# subnetwork 16
# weights before rebalancing: [[0.20036872 0.20000239 0.1998646  0.20007655 0.19968775]]
# weights after rebalancing [[0.20036872 0.20000239 0.1998646  0.20007655 0.19968775]]
# new portfolio wealth: [1.0254381]
# subnetwork 17
# weights before rebalancing: [[0.19959071 0.19968218 0.20018831 0.20124415 0.19929464]]
# weights after rebalancing [[0.19959071 0.19968218 0.20018831 0.20124415 0.19929464]]
# new portfolio wealth: [1.0191063]
# subnetwork 18
# weights before rebalancing: [[0.2009862  0.19836171 0.2006762  0.20086367 0.19911218]]
# weights after rebalancing [[0.2009862  0.19836171 0.2006762  0.20086367 0.19911218]]
# new portfolio wealth: [1.0275226]
# subnetwork 19
# weights before rebalancing: [[0.19982691 0.19982487 0.20023222 0.20024864 0.19986734]]
# weights after rebalancing [[0.19982691 0.19982487 0.20023222 0.20024864 0.19986734]]
# new portfolio wealth: [1.0422187]
# subnetwork 20
# weights before rebalancing: [[0.20031561 0.19941182 0.19979036 0.19982499 0.20065722]]
# weights after rebalancing [[0.20031561 0.19941182 0.19979036 0.19982499 0.20065722]]
# new portfolio wealth: [1.0321786]
# subnetwork 21
# weights before rebalancing: [[0.19960915 0.20032516 0.20000069 0.19950637 0.20055869]]
# weights after rebalancing [[0.19960915 0.20032516 0.20000069 0.19950637 0.20055869]]
# new portfolio wealth: [1.0312387]
# subnetwork 22
# weights before rebalancing: [[0.20016672 0.1999475  0.20033918 0.19975835 0.19978826]]
# weights after rebalancing [[0.20016672 0.1999475  0.20033918 0.19975835 0.19978826]]
# new portfolio wealth: [1.0353907]
# subnetwork 23
# weights before rebalancing: [[0.20061198 0.19931188 0.20074856 0.19968335 0.19964422]]
# weights after rebalancing [[0.20061198 0.19931188 0.20074856 0.19968335 0.19964422]]
# new portfolio wealth: [1.0396025]
# subnetwork 24
# weights before rebalancing: [[0.1996205  0.20025201 0.20061335 0.20029877 0.19921535]]
# weights after rebalancing [[0.1996205  0.20025201 0.20061335 0.20029877 0.19921535]]
# new portfolio wealth: [1.0454923]
# subnetwork 25
# weights before rebalancing: [[0.20045815 0.20078237 0.20021339 0.198865   0.19968115]]
# weights after rebalancing [[0.20045815 0.20078237 0.20021339 0.198865   0.19968115]]
# new portfolio wealth: [1.0394711]
# subnetwork 26
# weights before rebalancing: [[0.19921434 0.19950676 0.19921137 0.19937314 0.20269436]]
# weights after rebalancing [[0.19921434 0.19950676 0.19921137 0.19937314 0.20269436]]
# new portfolio wealth: [1.0004103]
# subnetwork 27
# weights before rebalancing: [[0.19936714 0.20142856 0.20055902 0.19891998 0.19972529]]
# weights after rebalancing [[0.19936714 0.20142856 0.20055902 0.19891998 0.19972529]]
# new portfolio wealth: [1.0143018]
# subnetwork 28
# weights before rebalancing: [[0.20056811 0.20040096 0.19926415 0.19962487 0.20014188]]
# weights after rebalancing [[0.20056811 0.20040096 0.19926415 0.19962487 0.20014188]]
# new portfolio wealth: [1.0186434]
# subnetwork 29
# weights before rebalancing: [[0.20070691 0.20089167 0.19920404 0.19921352 0.19998382]]
# weights after rebalancing [[0.20070691 0.20089167 0.19920404 0.19921352 0.19998382]]
# new portfolio wealth: [1.0325948]
# subnetwork 30
# weights before rebalancing: [[0.20015885 0.20021154 0.19978285 0.20003404 0.1998128 ]]
# weights after rebalancing [[0.20015885 0.20021154 0.19978285 0.20003404 0.1998128 ]]
# new portfolio wealth: [1.0359709]
# subnetwork 31
# weights before rebalancing: [[0.20011674 0.20188631 0.20084359 0.19818176 0.19897158]]
# weights after rebalancing [[0.20011674 0.20188631 0.20084359 0.19818176 0.19897158]]
# new portfolio wealth: [1.0258236]
# subnetwork 32
# weights before rebalancing: [[0.20037727 0.19955157 0.19972116 0.20152417 0.19882588]]
# weights after rebalancing [[0.20037727 0.19955157 0.19972116 0.20152417 0.19882588]]
# new portfolio wealth: [1.0432814]
# subnetwork 33
# weights before rebalancing: [[0.20051207 0.20099938 0.19819663 0.20039663 0.19989526]]
# weights after rebalancing [[0.20051207 0.20099938 0.19819663 0.20039663 0.19989526]]
# new portfolio wealth: [1.0295346]
# subnetwork 34
# weights before rebalancing: [[0.2004177  0.19961356 0.19955736 0.19969197 0.20071942]]
# weights after rebalancing [[0.2004177  0.19961356 0.19955736 0.19969197 0.20071942]]
# new portfolio wealth: [1.0263131]
# subnetwork 35
# weights before rebalancing: [[0.20243931 0.19702852 0.20154077 0.19805804 0.20093338]]
# weights after rebalancing [[0.20243931 0.19702852 0.20154077 0.19805804 0.20093338]]
# new portfolio wealth: [1.0570434]
# subnetwork 36
# weights before rebalancing: [[0.20081817 0.19899578 0.19932704 0.20023519 0.20062381]]
# weights after rebalancing [[0.20081817 0.19899578 0.19932704 0.20023519 0.20062381]]
# new portfolio wealth: [1.0552862]
# subnetwork 37
# weights before rebalancing: [[0.19939916 0.19999512 0.20035896 0.2002669  0.19997989]]
# weights after rebalancing [[0.19939916 0.19999512 0.20035896 0.2002669  0.19997989]]
# new portfolio wealth: [1.0507841]
# subnetwork 38
# weights before rebalancing: [[0.20003241 0.19967276 0.2006722  0.20033745 0.19928518]]
# weights after rebalancing [[0.20003241 0.19967276 0.2006722  0.20033745 0.19928518]]
# new portfolio wealth: [1.0455226]
# subnetwork 39
# weights before rebalancing: [[0.19988893 0.20006992 0.2001501  0.19975919 0.20013182]]
# weights after rebalancing [[0.19988893 0.20006992 0.2001501  0.19975919 0.20013182]]
# new portfolio wealth: [1.071373]
# tensor([1.0714], grad_fn=<StackBackward0>)

# %% [markdown]
# $\text{error} = - \left( -\left(1.071373 - \frac{4}{2}\right)^2 \right) = 0.8623$ where $\gamma$ = 4
#
#
# backpropogation: $\frac{\partial \text{error}}{\partial \theta_i}$  for every single network paramters
#
# number of paramters: $40 \times 3 \times 5 \times 5$

# %%
class Optimize(nn.Module):
    def __init__(self, r, P, cov, Lambda, Delta, K, lb, ub, Rf, batch_size):
        super (Optimize, self).__init__()
        self.model = PortfolioModel(r, P, cov, Lambda, Delta, K, lb, ub, Rf, batch_size)
        self.criterion = UtilityLoss()
        self.optimizer = optim.Adam(self.model.parameters())
    def train(self, x_train, max_epoch, batch_size, save_path):
        self.model.train()
        num_samples = x_train.shape[0]
        num_batches = num_samples // batch_size

        print('### Training... ###')
        for epoch in range(1, max_epoch + 1):
            start_time = time.time()
            total_loss = 0.0
            for i in range(num_batches):
                start = i * batch_size
                end = start + batch_size
                x_batch = x_train[start:end]
                x_batch = torch.tensor(x_batch, dtype=torch.float32)

                output = self.model(x_batch)
                loss = self.criterion(output, gamma=4)
                total_loss += loss.item()
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

                print('Batch {:d}/{:d} Loss {:.6f}'.format(i, num_batches, loss), end='\r', flush=True)

            duration = time.time() - start_time
            loss = total_loss / num_batches
            print('Epoch {:d} Loss {:.6f} Duration {:.3f} seconds.'.format(epoch, loss, duration))
            if epoch % 100 == 0:
                torch.save(self.model.state_dict(), save_path.format(epoch))

    def test(self, x_test, save_path):
        print('### Testing... ###')
        self.model.eval()
        self.model.load_state_dict(torch.load(save_path))
        with torch.no_grad():
                output = self.model(x_test)
                loss = self.criterion(output, gamma=4)
#                 score = self.score(output,torch.exp(torch.tensor(0.03)),gamma=4)
#                 total_loss += loss.item()
#         test_loss = total_loss / x_test.shape[0]
        print('Test Loss {:.6f}'.format(loss))

            


P = 5 # number of stocks
cov = np.array([[0.15, 0.01, 0.01, 0.01, 0.01],
                [0.01, 0.15, 0.01, 0.01, 0.01],
                [0.01, 0.01, 0.15, 0.01, 0.01],
                [0.01, 0.01, 0.01, 0.15, 0.01],
                [0.01, 0.01, 0.01, 0.01, 0.15]]) 
Lambda = np.array([0.1, 0.1, 0.2, 0.2, 0.2])
Delta = 1 / 40 
r = 0.03 # return rate
Rf = np.exp(r * Delta) # risk free rate
K = 40 # number of period
M = 20000 # number of path 
lb =0 
ub = 0.5
save_path = 'model_epoch_100.pth'
max_epoch = 100
batch_size = 64
x_train = torch.ones((M, 1))  

trainer = Optimize(r, P, cov, Lambda, Delta, K, lb, ub, Rf, batch_size)
trainer.train(x_train, max_epoch,batch_size,save_path)
x_test = torch.ones((M, 1))  

trainer.test(x_test, save_path)
# Out:
# ### Training... ###
# /var/folders/7j/xmzhy8t5189442byfp7qk3_w0000gn/T/ipykernel_48247/4002888488.py:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_batch = torch.tensor(x_batch, dtype=torch.float32)
# Epoch 1 Loss 0.846711 Duration 212.668 seconds.
# Epoch 2 Loss 0.574640 Duration 210.946 seconds.
# Epoch 3 Loss 0.400673 Duration 212.224 seconds.
# Epoch 4 Loss 0.332274 Duration 210.287 seconds.
# Epoch 5 Loss 0.293542 Duration 197.118 seconds.
# Epoch 6 Loss 0.267236 Duration 199.324 seconds.
# Epoch 7 Loss 0.246936 Duration 200.074 seconds.
# Epoch 8 Loss 0.230881 Duration 197.179 seconds.
# Epoch 9 Loss 0.215124 Duration 202.823 seconds.
# Epoch 10 Loss 0.198942 Duration 210.802 seconds.
# Epoch 11 Loss 0.186038 Duration 217.485 seconds.
# Epoch 12 Loss 0.175350 Duration 198.275 seconds.
# Epoch 13 Loss 0.165689 Duration 202.673 seconds.
# Epoch 14 Loss 0.157514 Duration 204.119 seconds.
# Epoch 15 Loss 0.148784 Duration 197.369 seconds.
# Epoch 16 Loss 0.140443 Duration 210.085 seconds.
# Epoch 17 Loss 0.133843 Duration 205.018 seconds.
# Epoch 18 Loss 0.126499 Duration 212.589 seconds.
# Epoch 19 Loss 0.121149 Duration 202.983 seconds.
# Epoch 20 Loss 0.117165 Duration 196.470 seconds.
# Epoch 21 Loss 0.113905 Duration 218.628 seconds.
# Epoch 22 Loss 0.110451 Duration 206.467 seconds.
# Epoch 23 Loss 0.106928 Duration 206.234 seconds.
# Epoch 24 Loss 0.103184 Duration 210.729 seconds.
# Epoch 25 Loss 0.100104 Duration 196.279 seconds.
# Epoch 26 Loss 0.097502 Duration 193.819 seconds.
# Epoch 27 Loss 0.095555 Duration 192.645 seconds.
# Epoch 28 Loss 0.093620 Duration 192.944 seconds.
# Epoch 29 Loss 0.091258 Duration 193.186 seconds.
# Epoch 30 Loss 0.088950 Duration 191.999 seconds.
# Epoch 31 Loss 0.087614 Duration 192.893 seconds.
# Epoch 32 Loss 0.086507 Duration 191.351 seconds.
# Epoch 33 Loss 0.085234 Duration 191.325 seconds.
# Epoch 34 Loss 0.084274 Duration 195.737 seconds.
# Epoch 35 Loss 0.083540 Duration 192.563 seconds.
# Epoch 36 Loss 0.082596 Duration 192.900 seconds.
# Epoch 37 Loss 0.081678 Duration 193.161 seconds.
# Epoch 38 Loss 0.080767 Duration 194.494 seconds.
# Epoch 39 Loss 0.079971 Duration 191.667 seconds.
# Epoch 40 Loss 0.079003 Duration 191.147 seconds.
# Epoch 41 Loss 0.078061 Duration 191.358 seconds.
# Epoch 42 Loss 0.077080 Duration 190.641 seconds.
# Epoch 43 Loss 0.076106 Duration 190.897 seconds.
# Epoch 44 Loss 0.075444 Duration 190.294 seconds.
# Epoch 45 Loss 0.074274 Duration 190.812 seconds.
# Epoch 46 Loss 0.073511 Duration 190.230 seconds.
# Epoch 47 Loss 0.073135 Duration 191.591 seconds.
# Epoch 48 Loss 0.072811 Duration 192.160 seconds.
# Epoch 49 Loss 0.072445 Duration 190.382 seconds.
# Epoch 50 Loss 0.071734 Duration 190.425 seconds.
# Epoch 51 Loss 0.071446 Duration 191.303 seconds.
# Epoch 52 Loss 0.071210 Duration 190.102 seconds.
# Epoch 53 Loss 0.070934 Duration 189.895 seconds.
# Epoch 54 Loss 0.070633 Duration 190.050 seconds.
# Epoch 55 Loss 0.070414 Duration 192.224 seconds.
# Epoch 56 Loss 0.070217 Duration 188.891 seconds.
# Epoch 57 Loss 0.070062 Duration 188.516 seconds.
# Epoch 58 Loss 0.069835 Duration 188.375 seconds.
# Epoch 59 Loss 0.069585 Duration 188.496 seconds.
# Epoch 60 Loss 0.069450 Duration 188.476 seconds.
# Epoch 61 Loss 0.069301 Duration 188.354 seconds.
# Epoch 62 Loss 0.069083 Duration 188.452 seconds.
# Epoch 63 Loss 0.068971 Duration 188.294 seconds.
# Epoch 64 Loss 0.068875 Duration 188.645 seconds.
# Epoch 65 Loss 0.068787 Duration 189.037 seconds.
# Epoch 66 Loss 0.068700 Duration 188.686 seconds.
# Epoch 67 Loss 0.068610 Duration 188.156 seconds.
# Epoch 68 Loss 0.068520 Duration 188.060 seconds.
# Epoch 69 Loss 0.068428 Duration 188.496 seconds.
# Epoch 70 Loss 0.068317 Duration 188.533 seconds.
# Epoch 71 Loss 0.068224 Duration 188.181 seconds.
# Epoch 72 Loss 0.068152 Duration 188.196 seconds.
# Epoch 73 Loss 0.068085 Duration 188.313 seconds.
# Epoch 74 Loss 0.068020 Duration 189.087 seconds.
# Epoch 75 Loss 0.067941 Duration 188.361 seconds.
# Epoch 76 Loss 0.067848 Duration 188.319 seconds.
# Epoch 77 Loss 0.067727 Duration 188.588 seconds.
# Epoch 78 Loss 0.067623 Duration 188.305 seconds.
# Epoch 79 Loss 0.067476 Duration 188.314 seconds.
# Epoch 80 Loss 0.067391 Duration 188.354 seconds.
# Epoch 81 Loss 0.067315 Duration 188.365 seconds.
# Epoch 82 Loss 0.067249 Duration 188.277 seconds.
# Epoch 83 Loss 0.067189 Duration 188.302 seconds.
# Epoch 84 Loss 0.067130 Duration 189.292 seconds.
# Epoch 85 Loss 0.067059 Duration 188.384 seconds.
# Epoch 86 Loss 0.066953 Duration 188.241 seconds.
# Epoch 87 Loss 0.066862 Duration 188.284 seconds.
# Epoch 88 Loss 0.066788 Duration 188.260 seconds.
# Epoch 89 Loss 0.066686 Duration 188.362 seconds.
# Epoch 90 Loss 0.066628 Duration 188.444 seconds.
# Epoch 91 Loss 0.066577 Duration 188.965 seconds.
# Epoch 92 Loss 0.066529 Duration 188.213 seconds.
# Epoch 93 Loss 0.066482 Duration 189.245 seconds.
# Epoch 94 Loss 0.066437 Duration 188.429 seconds.
# Epoch 95 Loss 0.066393 Duration 188.375 seconds.
# Epoch 96 Loss 0.066349 Duration 188.210 seconds.
# Epoch 97 Loss 0.066310 Duration 188.187 seconds.
# Epoch 98 Loss 0.066274 Duration 188.268 seconds.
# Epoch 99 Loss 0.066240 Duration 188.126 seconds.
# Epoch 100 Loss 0.066206 Duration 188.200 seconds.
# ### Testing... ###
# Test Loss 0.066190

# %%
saved_model_path = 'model_epoch_100.pth'
saved_model = torch.load(saved_model_path)
model = PortfolioModel(r, P, cov, Lambda, Delta, K, lb, ub, Rf, batch_size)
model.load_state_dict(saved_model)
model.eval()
inputs = torch.ones((1))
output = model(inputs)
# Out:
# initial portfolio wealth: 1
# subnetwork 0
# weights before rebalancing: [[0.22404929 0.07468867 0.07468873 0.07469445 0.5518788 ]]
# weights after rebalancing [[0.24998738 0.08333535 0.08333541 0.08334179 0.5       ]]
# new portfolio wealth: [1.0337574]
# subnetwork 1
# weights before rebalancing: [[0.07426663 0.40769067 0.40769067 0.05517493 0.05517713]]
# weights after rebalancing [[0.07426663 0.40769067 0.40769067 0.05517493 0.05517713]]
# new portfolio wealth: [1.0391065]
# subnetwork 2
# weights before rebalancing: [[0.05463983 0.05464065 0.4037364  0.4000348  0.08694836]]
# weights after rebalancing [[0.05463983 0.05464065 0.4037364  0.4000348  0.08694836]]
# new portfolio wealth: [1.0744395]
# subnetwork 3
# weights before rebalancing: [[0.04310174 0.04311322 0.27700302 0.31830087 0.31848118]]
# weights after rebalancing [[0.04310174 0.04311322 0.27700302 0.31830087 0.31848118]]
# new portfolio wealth: [1.0906677]
# subnetwork 4
# weights before rebalancing: [[0.22591467 0.03361098 0.24646653 0.24835332 0.24565455]]
# weights after rebalancing [[0.22591467 0.03361098 0.24646653 0.24835332 0.24565455]]
# new portfolio wealth: [1.0905387]
# subnetwork 5
# weights before rebalancing: [[0.40037367 0.05771678 0.05771677 0.42647246 0.05772039]]
# weights after rebalancing [[0.40037367 0.05771678 0.05771677 0.42647246 0.05772039]]
# new portfolio wealth: [1.1179707]
# subnetwork 6
# weights before rebalancing: [[0.06581333 0.06585368 0.48629832 0.06581332 0.31622133]]
# weights after rebalancing [[0.06581333 0.06585368 0.48629832 0.06581332 0.31622133]]
# new portfolio wealth: [1.1180415]
# subnetwork 7
# weights before rebalancing: [[0.05620731 0.05753163 0.41476083 0.4152958  0.05620446]]
# weights after rebalancing [[0.05620731 0.05753163 0.41476083 0.4152958  0.05620446]]
# new portfolio wealth: [1.1344736]
# subnetwork 8
# weights before rebalancing: [[0.05626621 0.41561317 0.41562346 0.05624857 0.05624857]]
# weights after rebalancing [[0.05626621 0.41561317 0.41562346 0.05624857 0.05624857]]
# new portfolio wealth: [1.1720495]
# subnetwork 9
# weights before rebalancing: [[0.05008476 0.36935633 0.16090888 0.05002351 0.3696265 ]]
# weights after rebalancing [[0.05008476 0.36935633 0.16090888 0.05002351 0.3696265 ]]
# new portfolio wealth: [1.1702127]
# subnetwork 10
# weights before rebalancing: [[0.31358778 0.2877184  0.04246367 0.04246375 0.31376636]]
# weights after rebalancing [[0.31358778 0.2877184  0.04246367 0.04246375 0.31376636]]
# new portfolio wealth: [1.1591185]
# subnetwork 11
# weights before rebalancing: [[0.05656356 0.4177998  0.05654305 0.05654305 0.41255045]]
# weights after rebalancing [[0.05656356 0.4177998  0.05654305 0.05654305 0.41255045]]
# new portfolio wealth: [1.2101351]
# subnetwork 12
# weights before rebalancing: [[0.3046417  0.30307484 0.04193639 0.04250545 0.30784163]]
# weights after rebalancing [[0.3046417  0.30307484 0.04193639 0.04250545 0.30784163]]
# new portfolio wealth: [1.2129904]
# subnetwork 13
# weights before rebalancing: [[0.2059838  0.25570607 0.24617429 0.25731236 0.03482344]]
# weights after rebalancing [[0.2059838  0.25570607 0.24617429 0.25731236 0.03482344]]
# new portfolio wealth: [1.2263823]
# subnetwork 14
# weights before rebalancing: [[0.04200567 0.30076748 0.04200568 0.30590692 0.30931422]]
# weights after rebalancing [[0.04200567 0.30076748 0.04200568 0.30590692 0.30931422]]
# new portfolio wealth: [1.2238514]
# subnetwork 15
# weights before rebalancing: [[0.05705991 0.4216183  0.05710833 0.40715364 0.05705985]]
# weights after rebalancing [[0.05705991 0.4216183  0.05710833 0.40715364 0.05705985]]
# new portfolio wealth: [1.2529573]
# subnetwork 16
# weights before rebalancing: [[0.04557417 0.23602004 0.04557402 0.33674902 0.33608276]]
# weights after rebalancing [[0.04557417 0.23602004 0.04557402 0.33674902 0.33608276]]
# new portfolio wealth: [1.2471241]
# subnetwork 17
# weights before rebalancing: [[0.04145058 0.04145058 0.30628067 0.30620888 0.30460933]]
# weights after rebalancing [[0.04145058 0.04145058 0.30628067 0.30620888 0.30460933]]
# new portfolio wealth: [1.2527473]
# subnetwork 18
# weights before rebalancing: [[0.04038272 0.29838973 0.06458636 0.2982582  0.29838297]]
# weights after rebalancing [[0.04038272 0.29838973 0.06458636 0.2982582  0.29838297]]
# new portfolio wealth: [1.259811]
# subnetwork 19
# weights before rebalancing: [[0.40071493 0.05766241 0.05780961 0.42606622 0.0577468 ]]
# weights after rebalancing [[0.40071493 0.05766241 0.05780961 0.42606622 0.0577468 ]]
# new portfolio wealth: [1.2811774]
# subnetwork 20
# weights before rebalancing: [[0.0678678  0.50147897 0.27570194 0.06786782 0.08708346]]
# weights after rebalancing [[0.06806915 0.5        0.27651986 0.06806916 0.08734181]]
# new portfolio wealth: [1.311294]
# subnetwork 21
# weights before rebalancing: [[0.0432321  0.31925896 0.27516875 0.04320905 0.31913108]]
# weights after rebalancing [[0.0432321  0.31925896 0.27516875 0.04320905 0.31913108]]
# new portfolio wealth: [1.3377796]
# subnetwork 22
# weights before rebalancing: [[0.30502734 0.04147085 0.30642965 0.30550972 0.0415625 ]]
# weights after rebalancing [[0.30502734 0.04147085 0.30642965 0.30550972 0.0415625 ]]
# new portfolio wealth: [1.3470998]
# subnetwork 23
# weights before rebalancing: [[0.0427894  0.0427894  0.31017855 0.2881059  0.31613675]]
# weights after rebalancing [[0.0427894  0.0427894  0.31017855 0.2881059  0.31613675]]
# new portfolio wealth: [1.3990641]
# subnetwork 24
# weights before rebalancing: [[0.30673    0.30672994 0.30340403 0.04162467 0.04151139]]
# weights after rebalancing [[0.30673    0.30672994 0.30340403 0.04162467 0.04151139]]
# new portfolio wealth: [1.403603]
# subnetwork 25
# weights before rebalancing: [[0.0867192  0.08537443 0.1173576  0.6258492  0.08469962]]
# weights after rebalancing [[0.11588802 0.11409093 0.15683194 0.5        0.11318915]]
# new portfolio wealth: [1.409117]
# subnetwork 26
# weights before rebalancing: [[0.35460535 0.05284366 0.35463935 0.18991499 0.04799666]]
# weights after rebalancing [[0.35460535 0.05284366 0.35463935 0.18991499 0.04799666]]
# new portfolio wealth: [1.4091514]
# subnetwork 27
# weights before rebalancing: [[0.36980265 0.05005446 0.16796502 0.36213052 0.05004735]]
# weights after rebalancing [[0.36980265 0.05005446 0.16796502 0.36213052 0.05004735]]
# new portfolio wealth: [1.4225633]
# subnetwork 28
# weights before rebalancing: [[0.08780003 0.64875656 0.08779965 0.08784398 0.08779966]]
# weights after rebalancing [[0.12498459 0.5        0.12498406 0.12504716 0.12498407]]
# new portfolio wealth: [1.4840175]
# subnetwork 29
# weights before rebalancing: [[0.04358708 0.3220638  0.26869875 0.32206377 0.0435866 ]]
# weights after rebalancing [[0.04358708 0.3220638  0.26869875 0.32206377 0.0435866 ]]
# new portfolio wealth: [1.4815218]
# subnetwork 30
# weights before rebalancing: [[0.04215937 0.3114486  0.31151792 0.29158756 0.04328649]]
# weights after rebalancing [[0.04215937 0.3114486  0.31151792 0.29158756 0.04328649]]
# new portfolio wealth: [1.5008506]
# subnetwork 31
# weights before rebalancing: [[0.3055211  0.04135672 0.30552167 0.30552164 0.04207885]]
# weights after rebalancing [[0.3055211  0.04135672 0.30552167 0.30552164 0.04207885]]
# new portfolio wealth: [1.5594354]
# subnetwork 32
# weights before rebalancing: [[0.35175106 0.04760655 0.35149473 0.2012829  0.04786469]]
# weights after rebalancing [[0.35175106 0.04760655 0.35149473 0.2012829  0.04786469]]
# new portfolio wealth: [1.5560207]
# subnetwork 33
# weights before rebalancing: [[0.12959069 0.03959629 0.29257923 0.29142198 0.24681179]]
# weights after rebalancing [[0.12959069 0.03959629 0.29257923 0.29142198 0.24681179]]
# new portfolio wealth: [1.5800999]
# subnetwork 34
# weights before rebalancing: [[0.0328103  0.23988214 0.24243376 0.24243717 0.24243669]]
# weights after rebalancing [[0.0328103  0.23988214 0.24243376 0.24243717 0.24243669]]
# new portfolio wealth: [1.6014514]
# subnetwork 35
# weights before rebalancing: [[0.05281663 0.39026508 0.11160795 0.39026505 0.05504528]]
# weights after rebalancing [[0.05281663 0.39026508 0.11160795 0.39026505 0.05504528]]
# new portfolio wealth: [1.6313245]
# subnetwork 36
# weights before rebalancing: [[0.4036381  0.40363854 0.05462654 0.06276828 0.07532854]]
# weights after rebalancing [[0.4036381  0.40363854 0.05462654 0.06276828 0.07532854]]
# new portfolio wealth: [1.612508]
# subnetwork 37
# weights before rebalancing: [[0.04138639 0.30573198 0.30578688 0.30571106 0.04138375]]
# weights after rebalancing [[0.04138639 0.30573198 0.30578688 0.30571106 0.04138375]]
# new portfolio wealth: [1.6080562]
# subnetwork 38
# weights before rebalancing: [[0.41262832 0.41640925 0.05635487 0.05635487 0.05825268]]
# weights after rebalancing [[0.41262832 0.41640925 0.05635487 0.05635487 0.05825268]]
# new portfolio wealth: [1.677755]
# subnetwork 39
# weights before rebalancing: [[0.28193256 0.31619155 0.04280258 0.04280264 0.31627068]]
# weights after rebalancing [[0.28193256 0.31619155 0.04280258 0.04280264 0.31627068]]
# new portfolio wealth: [1.707058]

# %% [markdown]
# ## Outsample Score
# author use $V_0 = E[\phi(\eta,\hat{\Phi}]$ as outsample score to make comparison to LSMC and HJB solution
#
# In J.Wang's Hamilton–Jacobi–Bellman (HJB) paper, he defined value function as $$ V_\tau = \inf_{p \in P} \left( \mu_w^p V_w + \frac{1}{2} (\sigma_w^p)^2 V_{ww} \right) $$ where $\tau$ = T - t and terminal condition is $V(w,\tau=0)=(W-\frac{\gamma}{2})^2$
#
# In F.Cong's LSMC paper, he defined value function as $$ V_t(W_t) = L_t \left( W_t (R_f)^{\frac{T-t}{\delta t}} - \frac{\gamma}{2} \right)^2 $$ where  $$ L_t = \prod_{s=t}^{T} \left(1 - \frac{(E(R_{t}^{e}))^2}{(E(R_{t}^{e}))^2}\right) $$
#
# terminal condition is $$ V_T(W_T) = (W_T - \frac{\gamma}{2})^2 $$
#
# In our paper, terminal value function is $V_T(W_T) = (W_T - \frac{\gamma}{2})^2$, but author didn't explicitly define $V_t(W_t)$
# I believe $$V_t(W_t) = (W_{t+1}(R_f)^\frac{-1}{\delta t} - \frac{\gamma}{2})^2 $$ becasue LSMC is going backward dynamic, but DNN is going forward dynamic.
#
# if I used $V_t(W_t) = (W_{t+1}(R_f)^{\frac{-1}{\delta t}} - \frac{\gamma}{2})^2 $ equation, I get outsample score of 0.953. Author's outsample score is 0.829

# %% [markdown]
# ![Screen%20Shot%202023-11-28%20at%206.26.18%20PM.png](attachment:Screen%20Shot%202023-11-28%20at%206.26.18%20PM.png)

# %% [markdown]
# ## Efficient Frontier for terminal wealth
# $V_T(W_T) = (W_T - \frac{\gamma}{2})^2$, $\gamma$ is risk aversion
# - Increase gamma:
#   - Increases mean of terminal wealth $W_T$
#   - Increases standard deviation (risk) of terminal wealth
#
# - Decrease gamma:
#   - Decreases mean of terminal wealth $W_T$
#   - Decreases standard deviation (risk) of terminal wealth
#
# So, by varying gamma value, you can construct an efficient frontier and find optimal balance between risk and return.
#
#
#
# ![Screen%20Shot%202023-12-06%20at%208.48.14%20AM.png](attachment:Screen%20Shot%202023-12-06%20at%208.48.14%20AM.png)

# %% [markdown]
# ## AR(1) Model**: $R_k = \alpha + AR_{k-1} + \epsilon$
#
# $s_k = (W_k, R_{k-1})$, $\eta_k = \epsilon_k$, $W_{k+1} = W_k(g_k^TR_k + R_f)$, and $s_{k+1} = (W_k(g_k^TR_k + R_f), R_k)$

# %%
# !git clone https://github.com/Zhiwei2799/516-Code.git
# %cd 516-code 

# !python AR_main.py
# Out:
# Cloning into '516-Code'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 179 (delta 27), reused 0 (delta 0), pack-reused 132
# Receiving objects: 100% (179/179), 45.48 KiB | 3.03 MiB/s, done.
# Resolving deltas: 100% (103/103), done.
# /Users/zhiweilin/.Trash/516-Code 02-36-27-588/516-Code/516-Code/516-Code
# ### Training... ###
# /Users/zhiweilin/.Trash/516-Code 02-36-27-588/516-Code/516-Code/516-Code/ModelAR.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_batch_0 = torch.tensor(x_batch_0, dtype=torch.float32)
# /Users/zhiweilin/.Trash/516-Code 02-36-27-588/516-Code/516-Code/516-Code/ModelAR.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_batch_1 = torch.tensor(x_batch_1, dtype=torch.float32)
# Epoch 1 Loss 0.433304 Duration 86.586 seconds.
# Epoch 2 Loss 0.394164 Duration 83.724 seconds.
# Epoch 3 Loss 0.374783 Duration 82.560 seconds.
# Epoch 4 Loss 0.363778 Duration 79.166 seconds.
# Epoch 5 Loss 0.356713 Duration 79.564 seconds.
# Epoch 6 Loss 0.355943 Duration 80.328 seconds.
# Epoch 7 Loss 0.355891 Duration 81.450 seconds.
# Epoch 8 Loss 0.354167 Duration 82.454 seconds.
# Epoch 9 Loss 0.352235 Duration 78.600 seconds.
# Epoch 10 Loss 0.352233 Duration 79.064 seconds.

# %% [markdown]
# ## CCC-GARCH(1,1) MODEL:
# $$
# R_{k,i} = \mu_i + z_{k,i}
# $$
#
# $$
# z_{k,i} = \Sigma_{k,i}\epsilon_{k,i}
# $$
#
# $$
# \Sigma^2_{k+1,i} = \omega_{i} + \alpha_i\Sigma_{k,i}^2+\beta_i z_{k,i}^2, \quad i=1,....,p, \quad k=0,1,....,K-1
# $$
#
# $s_k = (W_k, \Sigma_{k}^2), \eta_k = z_k, R_k = \mu + \eta_k, \Sigma_{k+1,i}^2 = \omega_i + \alpha_i \Sigma_{k,i}^2 + \beta_i \eta_{k,i}^2$ $s_{k+1} =(W_k(g_k^TR_k + R_f), \Sigma_{k+1}^2) $

# %%
# !python Garch_main.py  # it's fast becasue I only used 1000 simulation and hyperparamters are meaningless
# Out:
# ### Training... ###
# /Users/zhiweilin/.Trash/516-Code 02-36-27-588/516-Code/516-Code/516-Code/ModelGarch.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_batch_0 = torch.tensor(x_batch_0, dtype=torch.float32)
# /Users/zhiweilin/.Trash/516-Code 02-36-27-588/516-Code/516-Code/516-Code/ModelGarch.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_batch_1 = torch.tensor(x_batch_1, dtype=torch.float32)
# Epoch 1 Loss 1.671422 Duration 2.033 seconds.
# Epoch 2 Loss 1.643501 Duration 1.745 seconds.
# Epoch 3 Loss 1.337870 Duration 1.989 seconds.
# Epoch 4 Loss 1.264090 Duration 1.655 seconds.
# Epoch 5 Loss 1.307884 Duration 1.796 seconds.
# Epoch 6 Loss 1.371516 Duration 1.832 seconds.
# Epoch 7 Loss 1.307490 Duration 2.012 seconds.
# Epoch 8 Loss 1.186080 Duration 1.773 seconds.
# Epoch 9 Loss 1.269052 Duration 1.997 seconds.
# Epoch 10 Loss 1.150815 Duration 1.905 seconds.

# %%
# !python IID_Return_main.py

# %%
class UtilityLoss(torch.nn.Module):
    def __init__(self):
        super(UtilityLoss, self).__init__()

    def forward(self, W, gamma):
        objective = - (W - gamma/2)**2
        return -objective.mean()
